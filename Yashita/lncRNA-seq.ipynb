# %%
lncRNA_file
# Out:
# 'c:\\Users\\Yashita\\Desktop\\lncRNAs DATA.txt'

# %%
# !code "{lncRNA_file}"

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Jun 12 14:10:49 2024

@author: Yashita
"""

import pandas as pd

lncRNA_file = r"c:\Users\Yashita\Desktop\lncRNAs DATA.txt"

with open(lncRNA_file, "r") as RNA_seq:
    content = RNA_seq.readlines()
print(content)
# Out:
# ['>URS00008C0A2F lncRNA from 1 species\n', 'AUGCAGUGACACUGACAAUAAUUUAAAGCAUUUUAGGGCUCUUAACGUUCAUCUCACUCGCUCUAGAGUGAAGGAGAGAG\n', 'CAGAGAGUACAGAGCAGGUCCUAGGUCCUCCCCCAGAUAUAGAAAAACCGCAGUUGGAGAGACUGACAGAAGUGCUGGAG\n', 'AGGAAGGGAGGCAGCAGGACGUGGAAAAUCUGGGAUUCAAGAACAGCUUCUGCUAUUAAUUAGCUGUGUGUCAUUUCAGG\n', 'CAAAUCACAAAAUCUCCAGGCCCCCAAAUCCCCAUUUGCGAAACGAGGUGACCUGCCUCAGUUUUCCUUCAUCCAGCGAU\n', 'AAAAUUCUACUAAAAAAUUUCCAACCCCAGAGCAAGCAUCAGGACUGUGCCUGAAGGGAUCCGGCUGCAUCUCAGUAAUA\n', 'UUCCACUCUUACAGGCUUAAAAAUAAAAAAGAAAAGAAAAGAAAACAAGAACAGUUUCACCAGCGUCAAUUGAGAACAGC\n', 'UGCUUCAACAGGCCCUGCUUUAUGUGGGCAGGUGGGGACAGGGAGUUGGCCCAGAAAACAGGACCCUCAUUUCCUGGAGC\n', 'CCCCAGGGCAGCUCCCCAACACCGUACACAACCUGCAUCAUUUACAGGAGCCAAAGGAGUUUUAGAAAUCAACUUCAUAG\n', 'AGUUGCUGUAUCAUUGUGUUAGUUUUGCCAUCCUAACCUAUACAGCGUCACUAAUCUCUCCCCUCGGAGUUGACUGCCUA\n', 'AAAACAAGCCAUGGAUACAGGUUCCAAAGACCCGGGGGUGAGGGAGCGGAGAGGGUGGGUGUCACCACCCCGUCCAGCUC\n', 'CAAGCUUUGUGUGCCCUGGAACUCUCCAUUUUAGGUCAUUGCUUCAGUUUCUUUUCUAAAAAAUUAGGCUGCUGCAAGGU\n', 'CAGCCUGA
# ...

# %%
RNA_id = []
Seq = []

for line in content:
    line = line.strip()
    if line.startswith(">"):
        RNA_id.append(line)
    if line.startswith(("A","U","G","C")):
        Seq.append(line)
        
    

        
        


#RNA_df=pd.DataFrame(content)
#print(RNA_df)

# %%
RNA_id
# Out:
# ['>URS00008C0A2F lncRNA from 1 species',
#  '>URS00026A23F2 lncRNA from 1 species',
#  '>URS000075D95B lncRNA from 1 species',
#  '>URS00007681C7 lncRNA from 1 species']

# %%
Seq
# Out:
# ['AUGCAGUGACACUGACAAUAAUUUAAAGCAUUUUAGGGCUCUUAACGUUCAUCUCACUCGCUCUAGAGUGAAGGAGAGAG',
#  'CAGAGAGUACAGAGCAGGUCCUAGGUCCUCCCCCAGAUAUAGAAAAACCGCAGUUGGAGAGACUGACAGAAGUGCUGGAG',
#  'AGGAAGGGAGGCAGCAGGACGUGGAAAAUCUGGGAUUCAAGAACAGCUUCUGCUAUUAAUUAGCUGUGUGUCAUUUCAGG',
#  'CAAAUCACAAAAUCUCCAGGCCCCCAAAUCCCCAUUUGCGAAACGAGGUGACCUGCCUCAGUUUUCCUUCAUCCAGCGAU',
#  'AAAAUUCUACUAAAAAAUUUCCAACCCCAGAGCAAGCAUCAGGACUGUGCCUGAAGGGAUCCGGCUGCAUCUCAGUAAUA',
#  'UUCCACUCUUACAGGCUUAAAAAUAAAAAAGAAAAGAAAAGAAAACAAGAACAGUUUCACCAGCGUCAAUUGAGAACAGC',
#  'UGCUUCAACAGGCCCUGCUUUAUGUGGGCAGGUGGGGACAGGGAGUUGGCCCAGAAAACAGGACCCUCAUUUCCUGGAGC',
#  'CCCCAGGGCAGCUCCCCAACACCGUACACAACCUGCAUCAUUUACAGGAGCCAAAGGAGUUUUAGAAAUCAACUUCAUAG',
#  'AGUUGCUGUAUCAUUGUGUUAGUUUUGCCAUCCUAACCUAUACAGCGUCACUAAUCUCUCCCCUCGGAGUUGACUGCCUA',
#  'AAAACAAGCCAUGGAUACAGGUUCCAAAGACCCGGGGGUGAGGGAGCGGAGAGGGUGGGUGUCACCACCCCGUCCAGCUC',
#  'CAAGCUUUGUGUGCCCUGGAACUCUCCAUUUUAGGUCAUUGCUUCAGUUUCUUUUCUAAAAAAUUAGGCUGCUGCAAGGU',
# ...
